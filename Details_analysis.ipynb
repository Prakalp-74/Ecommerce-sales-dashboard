# %%
import pandas as pd

# %%
df = pd.read_csv("Details_dataset.csv")

# %%
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Order ID', 'Amount', 'Profit', 'Quantity', 'Category', 'Sub-Category',
#        'PaymentMode'],
#       dtype='object')

# %%
df.groupby("PaymentMode")["PaymentMode"].count()
# Out:
# PaymentMode
# COD            684
# Credit Card    163
# Debit Card     202
# EMI            120
# UPI            331
# Name: PaymentMode, dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
df.sort_values(by="Order ID", ascending=True)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 574   B-25601      80     -56         4  Electronics  Electronic Games
# 1479  B-25601       8      -2         3     Clothing       Hankerchief
# 1094  B-25601      66     -12         5     Clothing             Stole
# 1423  B-25601    1275    1148         7    Furniture         Bookcases
# 839   B-25602     119      -5         8     Clothing             Saree
# ...       ...     ...     ...       ...          ...               ...
# 1460  B-26099       9       3         1     Clothing             Skirt
# 1005  B-26099     207      37         4     Clothing       Hankerchief
# 279   B-26100      34      10         2     Clothing           T-shirt
# 819   B-26100      72      16         2     Clothing             Shirt
# 90    B-26100     828     230         2    Furniture            Chairs
#
#       PaymentMode
# 574           UPI
# 1479  Credit Card
# 1094          UPI
# 1423          EMI
# ...
